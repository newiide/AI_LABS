# %% [markdown]
# ## Лабораторна робота №3.
# ***Data Pre-Processing***

# %% [markdown]
# Оцінювання даної роботи буде ураховувати якість ваших візуалізацій (вони можуть незначно відрізнятися від прикладів, але повинні змістовно відображати суть задачі) та опис отриманих вами результатів. При наявності ЛИШЕ візуалізацій без роз'яснень, робота оцінюватися НЕ БУДЕ.
#
# Під час виконання вам дозволено користуватися будь-якими зручними для вас бібліотеками для візуалізації.
#
# Роботи ідентифіковані як ІДЕНТИЧНІ одразу отримують 0 балів.

# %% [markdown]
# Для виконання цієї лабораторної роботи Вам необхідно скористатися вибіркою [titanic.csv](https://gist.github.com/michhar/2dfd2de0d4f8727f873422c5d959fff5).
# Цей датасет ви вже використовували в лабораторній роботі №1 ;)
#
#   ```NB:побудовані графіки та гістограми мають бути змістовними і візуально зрозумілими.```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
sns.set_context('talk')

# %% [markdown]
# ***Завдання 1.*** Перед початком роботи з будь яким датасетом, необхідно:
# - завантажити датасет;
# - вивести основну статистичну інформацію по числовим змінним;
# - вивести розмірність датасету;
# - перевірити типи змінних і кількість данних по кожній змінній.

# %%
dataset = pd.read_csv('../datasets/titanic.csv')
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ***Завдання 2.*** Визначити кількість пропущених значень по кожному атрибуту

# %%
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 3:*** Побудувати матрицю кореляції

# %% [markdown]
# 1.   Вирахувати кореляційні коефіціенти для набору данних за методом Пірсона
# 2.   Відобразити отриману матрицю коефіціентів у вигляді теплокарти
#
# 3. Описати отримані результати, спираючись на значення коефіціентів кореляції

# %%
numeric_dataset = dataset.select_dtypes(include=['number'])

correlation_matrix = numeric_dataset.corr(method='pearson')

plt.figure(figsize=(12, 7))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Ваші висновки:
# Негативна кореляція між класом (Pclass) і виживаністю (Survived) на рівні -0.34. пасажири вищого класу (1-й клас) мали більший шанс вижити
#
# Кореляція між Fare (вартість квитка) і Survived дорівнює 0.26. пасажири, які заплатили більше за квиток, мали вищі шанси вижити, що корелює з класом
#
# SibSp (кількість братів/сестер) і Parch (батьки/діти) мають позитивну кореляцію (0.41). сім’ї з дітьми частіше подорожували разом
#
# Pclass і Fare мають кореляцію -0.55. пасажири 1-го класу платили значно більше, ніж пасажири нижчих класів
#
# Age і Pclass мають слабку негативну кореляцію (-0.37), що може означати, що в нижчих класах подорожувало більше молодших пасажирів

# %% [markdown]
# **Завдання 4:** Як ви могли помітити, у нашому датесеті досить багато пропущених значень, зокрема у атрибута віку пасажирів. Робота з такими даними впливае як на результат моделювання так і на загалом уявлення цілісної картини про дані. Тож для того, що позбавитися пропусків ми використаємо заповнення пропущених значень медіаною за групами.
#
#
#
# 1.   Напишіть функцію, що на вхід приймає датафрейм, назву колонки з пропущеними значеннями та список групуючих колонок та повертає датафрейм з заповненими пропущеними значеннями
# 2.   Наведіть приклад роботи функції та зробіть перевірку на пропущені значення (дивись **завдання 2**)

# %%
def fill_missing_data(dataset, column, group_cols):
    dataset = dataset.copy()
    dataset[column] = dataset[column].fillna(dataset.groupby(group_cols)[column].transform("median"))
    return dataset

df_filled = fill_missing_data(dataset, "Age", ["Pclass", "Sex"])

print(df_filled.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Ваші висновки:

# %% [markdown]
#
# ***Завдання 5:*** В моделях машинного навчання інснує велика проблема опрацювання безперервних змінних. Потрібно перетворити безперервні значення в категоріальні.
#
# Максимальний вік пасажира - ```80 років```.
#
# Отже, давайте розділимо діапазон від ```0 до 80``` на ```5``` осередків.
#
#
# Додайте до нашого датасету нову колонку ```Age_bin```, в якій будуть значення ```0, 1, 2, 3, 4```відповідно кожній віковій групі.
#
# Побудуйте графік, який відображає кількість виживших у кожній віковій категорії.

# %%
bins= [0, 16, 32, 48, 64, 80]
labels = [0, 1, 2, 3, 4]
dataset['Age_bin'] = pd.cut(dataset['Age'], bins=bins, labels=labels, include_lowest = True, right=False)

plt.figure(figsize=(8, 5))
sns.countplot(x="Age_bin", hue="Survived", data=dataset, palette="Set1")

plt.xlabel("Age")
plt.ylabel("Amount of passengers")
plt.title("Survived vs Age")
plt.legend(title="Survived", labels=["No", "Yes"])

plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 6:*** Так як змінна ```fare``` також є неперервною її треба закодувати до ```порядкової шкали```
# Для цього скоритайтесь функцією ```pandas.qcut```.
# [pandas.qcut](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html)
# - необхідно перевірити, чи є вірною гіпотеза про те, що кількість виживших пасажирів для квартильних значеннь змінної ```fare``` відрізняється, та чи доцільно використовувати кодування на цю змінну(для подальшої роботи з закодованою фичею)

# %%
dataset["Fare_category"] = pd.qcut(dataset["Fare"], q=4, labels=[1, 2, 3, 4])

fare_survival_table = pd.crosstab(dataset["Fare_category"], dataset["Survived"], margins=True)

fare_survival_table["Survival Rate (%)"] = fare_survival_table[1] / fare_survival_table["All"] * 100
fare_survival_table = fare_survival_table.drop('All')

plt.figure(figsize=(8, 6))
plt.bar(fare_survival_table.index.astype(int), fare_survival_table["Survival Rate (%)"], color = '#f478f0')

plt.xlabel('Fare Category')
plt.xticks(range(1, 5)) 
plt.ylabel('Survival Rate (%)')
plt.title('Survival Rate by Fare Category')

plt.show()
fare_survival_table
# Out:
# Survived         0    1  All  Survival Rate (%)
# Fare_category
# 1              179   44  223          19.730942
# 2              156   68  224          30.357143
# 3              121  101  222          45.495495
# 4               93  129  222          58.108108

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 7:*** Необхідно створити нові змінні ```Family_size``` та ```Alone``` та проаналізувати їх. Змінна ```Family_size``` передає суму змінних ```Parch``` та ```SibSp```. Змінна ```Family_size``` буде відібражати комбіновані дані, які необхідні для перевірки гіпотези, що ```виживання пасажирів залежіть від кількості членів їх сім'ї```. Змінна ```Alone``` позначає наявніть сім'ї.

# %%
dataset["Family_size"] = dataset["SibSp"] + dataset["Parch"]
dataset["Alone"] = (dataset["Family_size"] == 0).astype(int)

survival_by_family_size = dataset.groupby('Family_size')['Survived'].mean()

plt.figure(figsize=(10, 6))
survival_by_family_size.plot(kind='bar', color='#f478f0', edgecolor='black')

plt.title('Survival rate vs family size')
plt.xlabel('Family size')
plt.ylabel('Survival rate')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
alone_survival = dataset.groupby("Alone")["Survived"].mean() * 100

plt.figure(figsize=(6, 5))
plt.bar(["With Family", "Alone"], alone_survival, color=['#f478f0', '#f478f0'])

plt.xlabel("Alone or With Family")
plt.ylabel("Survival Rate (%)")
plt.title("Survival Rate: Alone vs With Family")

plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 8:*** Видалити атрибути які є ***НЕрелевантними*** або містять багато пропущених значень. Аргументувати свій вибір.

# %%
dataset.info()

dataset = dataset.drop(columns=["PassengerId", "Ticket", "Cabin"])

dataset.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    891 non-null    int64
#  1   Survived       891 non-null    int64
#  2   Pclass         891 non-null    int64
#  3   Name           891 non-null    object
#  4   Sex            891 non-null    object
#  5   Age            714 non-null    float64
#  6   SibSp          891 non-null    int64
#  7   Parch          891 non-null    int64
#  8   Ticket         891 non-null    object
#  9   Fare           891 non-null    float64
#  10  Cabin          204 non-null    object
#  11  Embarked       889 non-null    object
#  12  Age_bin        713 non-null    category
#  13  Fare_category  891 non-null    category
#  14  Family_size    891 non-null    int64
#  15  Alone          891 non-null    int64
# dtypes: category(2), float64(2), int64(7), object(5)
# memory usage: 99.7+ KB
# ...

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 9:*** Перетворіть змінні ```Sex```, ```Embarked``` та ```Title``` в числові значення

# %%
def extract_title(name):
    if "Miss." in name:
        return "Miss."
    elif "Mrs." in name:
        return "Mrs."
    elif "Mr." in name:
        return "Mr."
    
    return None

dataset['Title'] = dataset["Name"].map(extract_title)
dataset["Sex"] = dataset["Sex"].astype("category").cat.codes
dataset["Embarked"] = dataset["Embarked"].astype("category").cat.codes
dataset["Title"] = dataset["Title"].astype("category").cat.codes

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Survived       891 non-null    int64
#  1   Pclass         891 non-null    int64
#  2   Name           891 non-null    object
#  3   Sex            891 non-null    int8
#  4   Age            714 non-null    float64
#  5   SibSp          891 non-null    int64
#  6   Parch          891 non-null    int64
#  7   Fare           891 non-null    float64
#  8   Embarked       891 non-null    int8
#  9   Age_bin        713 non-null    category
#  10  Fare_category  891 non-null    category
#  11  Family_size    891 non-null    int64
#  12  Alone          891 non-null    int64
#  13  Title          891 non-null    int8
# dtypes: category(2), float64(2), int64(6), int8(3), object(1)
# memory usage: 67.5+ KB

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 10.*** Побудувати графіки всіх категоріальних змінних та проаналізувати скільки кожна категорія містить даних
#
# 1.   виділити категоріальні змінні
# 2.   побудувати сітку графіків кількості спотрережень по кожній категорії

# %%
categorical_columns = ["Survived", "Pclass", "Sex", "Embarked", "Alone", "Family_size"]
colors_for_columns = ["#f478f0", "#f478f0", "#f478f0", "#f478f0", "#f478f0", "#f478f0"]

fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
axes = axes.flatten()

for i, column in enumerate(categorical_columns):
    sns.countplot(x=dataset[column], ax=axes[i], color=colors_for_columns[i])
    axes[i].set_title(f'графік {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Count")

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ***Завдання 11.*** Побудувати діаграми розподілу всіх числових змінних

# %%
dataset["Age"] = dataset["Age"].dropna().astype(int)
numerical_columns = ["Age", "Fare", "Family_size"]

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

for i, column in enumerate(numerical_columns):
    sns.histplot(dataset[column], ax=axes[i], color="#f478f0")
    axes[i].set_title(f'Розподіл {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Кількість")


plt.tight_layout()
plt.show()

# %% [markdown]
# Ваші висновки:

# %% [markdown]
# ##Співвіднонешшя між всіма числовими змінними
#
# ***Завдання 12.*** В деяких випадках візуалізація співвідношення між змінними (числовими, категоріальними) дає можливість побачити викиди в змінних та знайти приховані тенденції і виділити навіть додаткові змінні. Тому, необхідно:
# 1) побудувати графіки співвідношення між всіма числовими змінними.
# 2) описати отримані співвідношення і запропонувати як їх можна (чи не можна) використати

# %%
numerical_columns = ["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked", "Family_size", "Alone", "Title"]
correlation_matrix = dataset[numerical_columns].corr()

plt.figure(figsize=(15, 9))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Кореляція між числовими змінними")
plt.show()

# %% [markdown]
# Ваші висновки:
#
#
# SibSp та Family_size (0.89) - сильна позитивна кореляція, бо розмір сім’ї залежить від кількості братів/сестер
# Parch та Family_size (0.78) - схоже, оскільки кількість батьків/дітей також впливає на загальний розмір сім’ї
# Sex та Survived (-0.54) - середня негативна кореляція вказує на те, що стать має значний вплив на виживання (жінки виживали частіше)
# Pclass та Fare (-0.55) - вищий клас має вищу вартість квитка
# Age має слабкий зв’язок з іншими змінними бо вік не є ключовим фактором у виживанні
# Survived та Fare (0.26) - дорожчі квитки могли збільшити шанси на виживання
#
# Клас каюти та ціна квитка важливі для виживання, розмір сім’ї впливає на виживання. можливо, ті, хто подорожували самі, мали менше шансів
# Стать є значущим фактором, бо жінок та дітей пропускали вперед

# %% [markdown]
# Кожне правильно виконане завдання буде оцінюватись в ```2 бали```.
